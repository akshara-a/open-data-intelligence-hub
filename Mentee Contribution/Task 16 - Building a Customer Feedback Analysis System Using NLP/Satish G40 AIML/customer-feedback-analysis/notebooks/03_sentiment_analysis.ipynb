# %% [markdown]
# # 03. Sentiment Analysis
#
# This notebook trains a sentiment model using TF-IDF and Logistic Regression.

# %%
from src.sentiment_model import train_sentiment_model, predict_sentiment

metrics = train_sentiment_model()
print(metrics['classification_report'])
print('Accuracy:', metrics['accuracy'])
print('Prediction:', predict_sentiment('The app is very slow and payment failed twice.'))
