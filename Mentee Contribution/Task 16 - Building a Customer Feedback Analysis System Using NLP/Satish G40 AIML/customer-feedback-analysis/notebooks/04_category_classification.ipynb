# %% [markdown]
# # 04. Category Classification
#
# This notebook trains a multi-label category classifier using TF-IDF and OneVsRest Logistic Regression.

# %%
from src.category_model import train_category_model, predict_categories

metrics = train_category_model()
print(metrics)
print('Predicted categories:', predict_categories('The app is slow and payment keeps failing', threshold=0.4))
