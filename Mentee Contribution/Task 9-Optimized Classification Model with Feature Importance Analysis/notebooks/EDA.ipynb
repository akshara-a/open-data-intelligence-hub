# %%
df.shape

# %%
python

# %%
import pandas as pd

df = pd.read_csv("data/heart.csv")

print(df.columns)

# %%
import os

print(os.getcwd())

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df.duplicated().sum()

# %%
df.columns
